# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel("C:\\Users\\ganch\\Desktop\\GANS\\Final_Results\\EpochTest\\loss_Di.xlsx")
df2 = pd.read_excel("C:\\Users\\ganch\\Desktop\\GANS\\Final_Results\\EpochTest\\loss_Dz.xlsx")
df3 = pd.read_excel("C:\\Users\\ganch\\Desktop\\GANS\\Final_Results\\EpochTest\\loss_EG.xlsx")

# %%
df = pd.concat([df1,df2,df3],axis = 0)

# %%
label1 = []
label2 = []
label3  = []
for i in range(12087):
    label1.append("Di")
    label2.append("Dz")
    label3.append("EG")

# %%
label_df = pd.concat([pd.DataFrame(label1),pd.DataFrame(label2),pd.DataFrame(label3)])

# %%
df1
# Out:
#        Unnamed: 0         0
# 0               0  2.960934
# 1               1  4.203137
# 2               2  3.900254
# 3               3  3.687676
# 4               4  3.943233
# 5               5  4.230370
# 6               6  4.183647
# 7               7  4.061889
# 8               8  4.122648
# 9               9  4.143414
# 10             10  4.084019
# 11             11  4.021515
# 12             12  3.926982
# 13             13  3.738339
# 14             14  3.743543
# 15             15  4.093334
# 16             16  3.643418
# 17             17  3.481291
# 18             18  3.641106
# 19             19  3.062913
# 20             20  3.458698
# 21             21  3.096782
# 22             22  3.174381
# 23             23  2.909592
# 24             24  2.990092
# 25             25  2.681387
# 26             26  2.534716
# 27             27  2.886773
# 28             28  2.216028
# 29             29  2.290213
# ...           ...       ...
# 12057       12057  0.017946
# ...

# %%
df["label"] = label_df

# %%
df
# Out:
#        Unnamed: 0         0 label
# 0               0  2.960934    Di
# 1               1  4.203137    Di
# 2               2  3.900254    Di
# 3               3  3.687676    Di
# 4               4  3.943233    Di
# 5               5  4.230370    Di
# 6               6  4.183647    Di
# 7               7  4.061889    Di
# 8               8  4.122648    Di
# 9               9  4.143414    Di
# 10             10  4.084019    Di
# 11             11  4.021515    Di
# 12             12  3.926982    Di
# 13             13  3.738339    Di
# 14             14  3.743543    Di
# 15             15  4.093334    Di
# 16             16  3.643418    Di
# 17             17  3.481291    Di
# 18             18  3.641106    Di
# 19             19  3.062913    Di
# 20             20  3.458698    Di
# 21             21  3.096782    Di
# 22             22  3.174381    Di
# 23             23  2.909592    Di
# 24             24  2.990092    Di
# 25             25  2.681387    Di
# ...

# %%
df.to_excel("C:\\Users\\ganch\\Desktop\\GANS\\Final_Results\\EpochTest\\Plot_EpochTest.xlsx")

# %%
plt.plot(df3[0])
